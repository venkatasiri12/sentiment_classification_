# %% [markdown]
# # 09_utils_and_requirements

# %% [markdown]
# Utilities, README and requirements.

# %%
readme = 'Sentiment project - notebooks included. See README.txt'
with open('README.txt','w',encoding='utf-8') as f: f.write(readme)
req = '\n'.join(['datasets','transformers','accelerate','evaluate','scikit-learn','pandas','numpy','joblib','tensorflow>=2.11','shap','lime','streamlit','fastapi','uvicorn'])
with open('requirements.txt','w',encoding='utf-8') as f: f.write(req)
print('Wrote README.txt and requirements.txt')
